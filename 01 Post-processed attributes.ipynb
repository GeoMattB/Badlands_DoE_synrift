# %% [markdown]
# # Post-processed attributes
#
# A number of useful attributes can be calculated, displayed and evaluated from the standard Badlands outputs.
#
# The structure for the functions that generate these attributes is:
#
#
# | Function      | description |
# | :---        |    :----:   |
# | attributeName      | generates the attribute for a single timstep       |
# | attributeName_experiment:   |generates the attribute for all the timesteps in an experiment |
# | attributeName_experiment_doegen:   |generates the attribute for a set of multiple experiments |
#
#
# Where possible, the inputs for each function are taken from the experiment configuration file (xml file).
#
# The multiprocessing module is used when it is possible, to speed up generation of attributes at the experiment or experiment_doegen level.
#
# ## Generate new .xmf files to view attributes in Paraview
#
# Paraview uses a set of .xmf files to decribe and display the properties within the outputs. The **postproc_xmf_update** utility updates these .xmf files to enable paraview to display the new properties.
#
# ## Transfer (interpolate) to stratigraphic grid
#
# By interpolating the attributes on to the final stratigraphic grid, paleo landscape properties can be viewed in their position at the end of the experiment time.
#
# *currently the interpolation is vertical to the final stratigraphic grid, experiments with horizontal displacment will misplace the interpolated data.*
#
# Functions:
#
# strat_flow_write(attribs, modelfile)  /  strat_tin_write(attribs, modelfile)
# + where attribs is a list of attributes and modelfile is the experiment xml configuration.
#
# strat_flow_write_doegen / strat_flow_write_doegen('badlands_xml',attributes)
# + the xml directory containing the xml configuration files.

# %%
#install the badlands_doe_toolset if not already installed
#!pip install badlands-doe-toolset

# %%
# Example showing interpolation of the lake and cumdiff attributes from set of experiments to the final stratigraphic grid.
# When the cumdiff attribute is added, instdiff is auotmatically generated.

import badlands_doe_toolset.postproc_utils as ppu

# ppu.strat_tin_write(attribs, modelfile) is the single model version of this where modelfile is the xml configuration.

attributes=['lake','cumdiff'] #this will also add the instdiff attribute.
ppu.strat_tin_write_doegen('badlands_xml',attributes)

# %% [markdown]
# # Fetch area calculation
# Badlands produces a basin ID for each catchment in each time interval in the experiment. Unfortunately, this ID is not consistent through all model time steps. In my case, shortly after subsidence is initiated, only one or 2 basin IDs are allocated to my model and I would like more detail.
#
# The flow.time.XX.hdf5 file contains information about the flow network connections. By examining where the stream / flow lines cross the boundary of the depocenter we can classify the upstream areas from the depocenter limts to examine fetch areas further.
#
# |<img src="images/fetch_area_setup.png" alt="geometry" width="400" height="200"/>|<img src="images/fetch_area_result.png" alt="geometry"  width="800" height="400"/>|
# |:-:|:-:|
# Shown in the left image is the depocenter surrounded by a series of black node points. These were generated in QGIS by digitising a line, then using the "points along geomoetry tool" to create a set of 360 points at regular points and each point assigned an ID from 1 to 360 at regular intervals.
#
# Once the fetch areas have been identifed at each timestep (lower right image) and associated with the node where they contact the depocenter, process changes over time occurring outside the depocenter can be examined in greater detail.
#
# Once again, we can use the multiprocessing module to calculate multiple timesteps / layers in parallel as each timestep is independent of the previous.
#
# The python module used here is NetworkX. Both upstream and downstream connections are tagged, however downstream connections from the input nodes are tagged with a negative ID. As the downstream connections will have input from multiple upstream nodes, extra care needs to be taken when interpreting the downstream fetch assignments as only 1 assignment is made when there are multiple inputs.
#
# If some nodes or flow paths are not tagged near to the boundary of the depocenter a larger interpolation distance (interp_dist=XXXX) may help.

# %%
# Here a single experiment has the fetch area for each step calculated.
import badlands_doe_toolset.postproc_utils as ppu
exp=ppu.fetch_area_experiment('badlands_xml/experiment_1.xml','data/fetch_node_file.csv')
# interp_dist=5000 is an optional parameter, by default it uses 2x the experiments dx value.

# You probably want to visualise fetch area in paraview.
# To do this you need to update the xmf files so paraview knows theres a new attribute.
import badlands_doe_toolset.postproc_xmf_update as ppxmfu
ppxmfu.flowfile_xmf('xml_test/experiment_1.xml')

# %%
#re-apply the fetch area calculation with a larger interpolation distance if not all flow paths are being captured.
import badlands_doe_toolset.postproc_utils as ppu
exp=ppu.fetch_area_experiment('badlands_xml/experiment_86.xml','data/fetch_node_file.csv',interp_dist=5000)

# %%
# DoEgen produces multiple experiments and here the list of experiments is supplied to the single experiment function.
# reads the xml directory, the nodefile for the fetch areas and iterates through all experiments to generate the fetch areas.
# While it is possible to produce this output for many models it is time consuming. 
# I would suggest being selective about which experiments this is done for.

# To do this selectively, copy the experiment xml files from the default directory to another:
# 
## Nexp=ppu.fetch_area_doegen('selected_xml','data/fetch_node_file.csv')
# interp_dist=5000 is an optional parameter, by default it uses 2x the dx value.

import badlands_doe_toolset.postproc_utils as ppu
Nexp=ppu.fetch_area_doegen('badlands_xml','data/fetch_node_file.csv')

# %%
#add the lake property to the xmf for visualisation
import badlands_doe_toolset.postproc_xmf_update as ppxmfu
for i in range(1,301):
    ppxmfu.flowfile_xmf('badlands_xml/experiment_'+str(i)+'.xml')

# %%
#add the lake property to the xmf for visualisation
import badlands_doe_toolset.postproc_xmf_update as ppxmfu
ppxmfu.tinfile_xmf('badlands_xml/experiment_86.xml')

# %% [markdown]
# # Terrain Roughness
# **Riley, 1999**
#
# Terrain_roughness is an attribute that quantifies how rapidly height changes using Rileys (Riley 1999) Terrain Roughness Index.
# This implementation uses the layElev attribute in the strat file with a sliding window to calculate the Terrain Roughness Index. Note that this method requires data is arranged on a regular, square grid to work (this is why we use the stratal file). A triangular mesh cannot be used to generate this property directly.
#
# Scale is important for this indicator and whle this uses a 3x3 sliding window it may be that larger say, 5x5 or 9x9 sliding windows are useful.
# If someone asks I may be able to add larger sliding windows as an option here.
# Very early implementation of this, visualisation and usefuleness of this should be reviewed and evaluation needs to be worked out.

# %%
import badlands_doe_toolset.postproc_utils as ppu
xmldir='badlands_xml'
ppu.strat_TerrRough_write_doegen(xmldir)

# %% [markdown]
# ## So what can I do with this? (D'accord, c'est quoi cette merde?)
#
# The outputs of fetch area calculations fixes one of the primary problems with badlands Basin ID in that it is not a location specific, unique ID throughout all experiment time steps. This makes it possible to dig deeper into how sediment supply varies in catchments and fetch areas over time. Similar to the rock tracking feature of badlands we can now compare erosion and deposition in more specific locations.
#
# There is still some work to do however, there is no erosion or deposition information in the flow.timeXX.hdf5 files. That information is in the tin.timeXX.hdf5 files which havee different shapes and indexes. To evaluate erosion and transient deposition within fetch areas we need both datasets to be consitent. Also, calculating sediment volume from erodep, or decompacted thicknesses require an area but all we have are connected nodes in a flow file, not a regular grid.
#
# Also, it's nice having all this data as maps with elevations when it was happening but I want to know about how all of these things look now in the stratigraphy.
#
# Our final stratal file (sed.timeXX.hdf5) has the same number of layers as timesteps. It is also a regular grid with each cell being the same size. By interpolating the tin.time and flow.time data onto the final stratal file we have all data in the same array shape and coordinates. Some information is lost (individual node connections), but the original files are there for that.

# %%
# reads timesteps from the tins and populates the final depth stratal file with the specified attributes
import badlands_doe_toolset.postproc_utils as ppu
attributes=['lake','cumdiff']
ppu.strat_tin_write_doegen('xml_test',attributes)

# %%
# reads the flows and populates the final stratal file with specified attributes
import badlands_doe_toolset.postproc_utils as ppu
attributes=['fetch']
ppu.strat_flow_write_doegen('xml_test',attributes)

# %%
import badlands_doe_toolset.postproc_utils as ppu
attributes=['cumhill']
modelfile='badlands_xml/experiment_86.xml'
ppu.strat_tin_write(attributes,modelfile)

# %%
#generate a vts volume for display in Paraview
# similar to the badlands-companion. 
# This adds all attributes with the "lay_" prefix in the stratal file generated above to a vts file for display in paraview.
import badlands_doe_toolset.postproc_utils as ppu

stratfile='Experiments/experiment_86/h5/sed.time300.hdf5'
vtsout='Experiments/experiment_86/sed.time300'
ppu.gridtovts(stratfile,vtsout)

# %%
#write instdiff [cumdiffN-1]-[cumdiffN] to tin files in a single experiment
import badlands_doe_toolset.postproc_utils as ppu
ppu.tin_write_instdiff('badlands_xml/experiment_86.xml')

# %%
#add the instdiff property to the xmf files for visualisation
import badlands_doe_toolset.postproc_xmf_update as ppxmfu
ppxmfu.tinfile_xmf('badlands_xml/experiment_86.xml')

# %%
#make a QGIS compatible mesh file from hdf5 tin
import badlands_doe_toolset.postproc_utils as ppu
ppu.TIN_hdf_to_2dm(outpath,hdf5_input)

# %%
import badlands_doe_toolset.postproc_utils as ppu
modelfile='badlands_xml/experiment_86.xml'
attribs=['fetch']
ppu.tin_write_flow_experiment(modelfile,attribs)

#update the xmf for visualisation
ppxmfu.tinfile_xmf(modelfile)
# Out:
# <function badlands_doe_toolset.postproc_xmf_update.tinfile_xmf(modelfile)>

# %%
#update the xmf for visualisation
ppxmfu.tinfile_xmf(modelfile)
# Out:
# reading Experiments/experiment_86/h5/tin.time0.hdf5
# output will be Experiments/experiment_86/xmf/tin.time0.xmf
# reading Experiments/experiment_86/h5/tin.time1.hdf5
# output will be Experiments/experiment_86/xmf/tin.time1.xmf
# reading Experiments/experiment_86/h5/tin.time2.hdf5
# output will be Experiments/experiment_86/xmf/tin.time2.xmf
# reading Experiments/experiment_86/h5/tin.time3.hdf5
# output will be Experiments/experiment_86/xmf/tin.time3.xmf
# reading Experiments/experiment_86/h5/tin.time4.hdf5
# output will be Experiments/experiment_86/xmf/tin.time4.xmf
# reading Experiments/experiment_86/h5/tin.time5.hdf5
# output will be Experiments/experiment_86/xmf/tin.time5.xmf
# reading Experiments/experiment_86/h5/tin.time6.hdf5
# output will be Experiments/experiment_86/xmf/tin.time6.xmf
# reading Experiments/experiment_86/h5/tin.time7.hdf5
# output will be Experiments/experiment_86/xmf/tin.time7.xmf
# reading Experiments/experiment_86/h5/tin.time8.hdf5
# output will be Experiments/experiment_86/xmf/tin.time8.xmf
# reading Experiments/experiment_86/h5/tin.time9.hdf5
# output will be Experiments/experiment_86/xmf/tin.time9.xmf
# reading Experiments/experiment_86/h5/tin.time10.hdf5
# output will be Experiments/experiment_86/xmf/tin.time10.xmf
# reading Experiments/experiment_86/h5/tin.time11.hdf5
# output will be Experiments/experiment_86/xmf/tin.time11.xmf
# reading Experiments/experiment_86/h5/tin.time12.hdf5
# output will be Experiments/experiment_86/xmf/tin.time12.xmf
# reading Experiments/experiment_86/h5/tin.time13.hdf5
# output will be Experiments/experiment_86/xmf/tin.time13.xmf
# reading Experiments/experiment_86/h5/tin.time14.hdf5
# output will be Experiments/experiment_86/xmf/tin.time14.xmf
# reading Experiments/experiment_86/h5/tin.time15.hdf5
# output will be Experiments/experiment_86/xmf/tin.time15.xmf
# reading Experiments/experiment_86/h5/tin.time16.hdf5
# output will be Experiments/experiment_86/xmf/tin.time16.xmf
# reading Experiments/experiment_86/h5/tin.time17.hdf5
# output will be Experiments/experiment_86/xmf/tin.time17.xmf
# reading Experiments/experiment_86/h5/tin.time18.hdf5
# output will be Experiments/experiment_86/xmf/tin.time18.xmf
# reading Experiments/experiment_86/h5/tin.time19.hdf5
# output will be Experiments/experiment_86/xmf/tin.time19.xmf
# reading Experiments/experiment_86/h5/tin.time20.hdf5
# output will be Experiments/experiment_86/xmf/tin.time20.xmf
# reading Experiments/experiment_86/h5/tin.time21.hdf5
# output will be Experiments/experiment_86/xmf/tin.time21.xmf
# reading Experiments/experiment_86/h5/tin.time22.hdf5
# output will be Experiments/experiment_86/xmf/tin.time22.xmf
# reading Experiments/experiment_86/h5/tin.time23.hdf5
# output will be Experiments/experiment_86/xmf/tin.time23.xmf
# reading Experiments/experiment_86/h5/tin.time24.hdf5
# output will be Experiments/experiment_86/xmf/tin.time24.xmf
# reading Experiments/experiment_86/h5/tin.time25.hdf5
# output will be Experiments/experiment_86/xmf/tin.time25.xmf
# reading Experiments/experiment_86/h5/tin.time26.hdf5
# output will be Experiments/experiment_86/xmf/tin.time26.xmf
# reading Experiments/experiment_86/h5/tin.time27.hdf5
# output will be Experiments/experiment_86/xmf/tin.time27.xmf
# reading Experiments/experiment_86/h5/tin.time28.hdf5
# output will be Experiments/experiment_86/xmf/tin.time28.xmf
# reading Experiments/experiment_86/h5/tin.time29.hdf5
# output will be Experiments/experiment_86/xmf/tin.time29.xmf
# reading Experiments/experiment_86/h5/tin.time30.hdf5
# output will be Experiments/experiment_86/xmf/tin.time30.xmf
# reading Experiments/experiment_86/h5/tin.time31.hdf5
# output will be Experiments/experiment_86/xmf/tin.time31.xmf
# reading Experiments/experiment_86/h5/tin.time32.hdf5
# output will be Experiments/experiment_86/xmf/tin.time32.xmf
# reading Experiments/experiment_86/h5/tin.time33.hdf5
# output will be Experiments/experiment_86/xmf/tin.time33.xmf
# reading Experiments/experiment_86/h5/tin.time34.hdf5
# output will be Experiments/experiment_86/xmf/tin.time34.xmf
# reading Experiments/experiment_86/h5/tin.time35.hdf5
# output will be Experiments/experiment_86/xmf/tin.time35.xmf
# reading Experiments/experiment_86/h5/tin.time36.hdf5
# output will be Experiments/experiment_86/xmf/tin.time36.xmf
# reading Experiments/experiment_86/h5/tin.time37.hdf5
# output will be Experiments/experiment_86/xmf/tin.time37.xmf
# reading Experiments/experiment_86/h5/tin.time38.hdf5
# output will be Experiments/experiment_86/xmf/tin.time38.xmf
# reading Experiments/experiment_86/h5/tin.time39.hdf5
# output will be Experiments/experiment_86/xmf/tin.time39.xmf
# reading Experiments/experiment_86/h5/tin.time40.hdf5
# output will be Experiments/experiment_86/xmf/tin.time40.xmf
# reading Experiments/experiment_86/h5/tin.time41.hdf5
# output will be Experiments/experiment_86/xmf/tin.time41.xmf
# reading Experiments/experiment_86/h5/tin.time42.hdf5
# output will be Experiments/experiment_86/xmf/tin.time42.xmf
# reading Experiments/experiment_86/h5/tin.time43.hdf5
# output will be Experiments/experiment_86/xmf/tin.time43.xmf
# reading Experiments/experiment_86/h5/tin.time44.hdf5
# output will be Experiments/experiment_86/xmf/tin.time44.xmf
# reading Experiments/experiment_86/h5/tin.time45.hdf5
# output will be Experiments/experiment_86/xmf/tin.time45.xmf
# reading Experiments/experiment_86/h5/tin.time46.hdf5
# output will be Experiments/experiment_86/xmf/tin.time46.xmf
# reading Experiments/experiment_86/h5/tin.time47.hdf5
# output will be Experiments/experiment_86/xmf/tin.time47.xmf
# reading Experiments/experiment_86/h5/tin.time48.hdf5
# output will be Experiments/experiment_86/xmf/tin.time48.xmf
# reading Experiments/experiment_86/h5/tin.time49.hdf5
# output will be Experiments/experiment_86/xmf/tin.time49.xmf
# reading Experiments/experiment_86/h5/tin.time50.hdf5
# output will be Experiments/experiment_86/xmf/tin.time50.xmf
# reading Experiments/experiment_86/h5/tin.time51.hdf5
# output will be Experiments/experiment_86/xmf/tin.time51.xmf
# reading Experiments/experiment_86/h5/tin.time52.hdf5
# output will be Experiments/experiment_86/xmf/tin.time52.xmf
# reading Experiments/experiment_86/h5/tin.time53.hdf5
# output will be Experiments/experiment_86/xmf/tin.time53.xmf
# reading Experiments/experiment_86/h5/tin.time54.hdf5
# output will be Experiments/experiment_86/xmf/tin.time54.xmf
# reading Experiments/experiment_86/h5/tin.time55.hdf5
# output will be Experiments/experiment_86/xmf/tin.time55.xmf
# reading Experiments/experiment_86/h5/tin.time56.hdf5
# output will be Experiments/experiment_86/xmf/tin.time56.xmf
# reading Experiments/experiment_86/h5/tin.time57.hdf5
# output will be Experiments/experiment_86/xmf/tin.time57.xmf
# reading Experiments/experiment_86/h5/tin.time58.hdf5
# output will be Experiments/experiment_86/xmf/tin.time58.xmf
# reading Experiments/experiment_86/h5/tin.time59.hdf5
# output will be Experiments/experiment_86/xmf/tin.time59.xmf
# reading Experiments/experiment_86/h5/tin.time60.hdf5
# output will be Experiments/experiment_86/xmf/tin.time60.xmf
# reading Experiments/experiment_86/h5/tin.time61.hdf5
# output will be Experiments/experiment_86/xmf/tin.time61.xmf
# reading Experiments/experiment_86/h5/tin.time62.hdf5
# output will be Experiments/experiment_86/xmf/tin.time62.xmf
# reading Experiments/experiment_86/h5/tin.time63.hdf5
# output will be Experiments/experiment_86/xmf/tin.time63.xmf
# reading Experiments/experiment_86/h5/tin.time64.hdf5
# output will be Experiments/experiment_86/xmf/tin.time64.xmf
# reading Experiments/experiment_86/h5/tin.time65.hdf5
# output will be Experiments/experiment_86/xmf/tin.time65.xmf
# reading Experiments/experiment_86/h5/tin.time66.hdf5
# output will be Experiments/experiment_86/xmf/tin.time66.xmf
# reading Experiments/experiment_86/h5/tin.time67.hdf5
# output will be Experiments/experiment_86/xmf/tin.time67.xmf
# reading Experiments/experiment_86/h5/tin.time68.hdf5
# output will be Experiments/experiment_86/xmf/tin.time68.xmf
# reading Experiments/experiment_86/h5/tin.time69.hdf5
# output will be Experiments/experiment_86/xmf/tin.time69.xmf
# reading Experiments/experiment_86/h5/tin.time70.hdf5
# output will be Experiments/experiment_86/xmf/tin.time70.xmf
# reading Experiments/experiment_86/h5/tin.time71.hdf5
# output will be Experiments/experiment_86/xmf/tin.time71.xmf
# reading Experiments/experiment_86/h5/tin.time72.hdf5
# output will be Experiments/experiment_86/xmf/tin.time72.xmf
# reading Experiments/experiment_86/h5/tin.time73.hdf5
# output will be Experiments/experiment_86/xmf/tin.time73.xmf
# reading Experiments/experiment_86/h5/tin.time74.hdf5
# output will be Experiments/experiment_86/xmf/tin.time74.xmf
# reading Experiments/experiment_86/h5/tin.time75.hdf5
# output will be Experiments/experiment_86/xmf/tin.time75.xmf
# reading Experiments/experiment_86/h5/tin.time76.hdf5
# output will be Experiments/experiment_86/xmf/tin.time76.xmf
# reading Experiments/experiment_86/h5/tin.time77.hdf5
# output will be Experiments/experiment_86/xmf/tin.time77.xmf
# reading Experiments/experiment_86/h5/tin.time78.hdf5
# output will be Experiments/experiment_86/xmf/tin.time78.xmf
# reading Experiments/experiment_86/h5/tin.time79.hdf5
# output will be Experiments/experiment_86/xmf/tin.time79.xmf
# reading Experiments/experiment_86/h5/tin.time80.hdf5
# output will be Experiments/experiment_86/xmf/tin.time80.xmf
# reading Experiments/experiment_86/h5/tin.time81.hdf5
# output will be Experiments/experiment_86/xmf/tin.time81.xmf
# reading Experiments/experiment_86/h5/tin.time82.hdf5
# output will be Experiments/experiment_86/xmf/tin.time82.xmf
# reading Experiments/experiment_86/h5/tin.time83.hdf5
# output will be Experiments/experiment_86/xmf/tin.time83.xmf
# reading Experiments/experiment_86/h5/tin.time84.hdf5
# output will be Experiments/experiment_86/xmf/tin.time84.xmf
# reading Experiments/experiment_86/h5/tin.time85.hdf5
# output will be Experiments/experiment_86/xmf/tin.time85.xmf
# reading Experiments/experiment_86/h5/tin.time86.hdf5
# output will be Experiments/experiment_86/xmf/tin.time86.xmf
# reading Experiments/experiment_86/h5/tin.time87.hdf5
# output will be Experiments/experiment_86/xmf/tin.time87.xmf
# reading Experiments/experiment_86/h5/tin.time88.hdf5
# output will be Experiments/experiment_86/xmf/tin.time88.xmf
# reading Experiments/experiment_86/h5/tin.time89.hdf5
# output will be Experiments/experiment_86/xmf/tin.time89.xmf
# reading Experiments/experiment_86/h5/tin.time90.hdf5
# output will be Experiments/experiment_86/xmf/tin.time90.xmf
# reading Experiments/experiment_86/h5/tin.time91.hdf5
# output will be Experiments/experiment_86/xmf/tin.time91.xmf
# reading Experiments/experiment_86/h5/tin.time92.hdf5
# output will be Experiments/experiment_86/xmf/tin.time92.xmf
# reading Experiments/experiment_86/h5/tin.time93.hdf5
# output will be Experiments/experiment_86/xmf/tin.time93.xmf
# reading Experiments/experiment_86/h5/tin.time94.hdf5
# output will be Experiments/experiment_86/xmf/tin.time94.xmf
# reading Experiments/experiment_86/h5/tin.time95.hdf5
# output will be Experiments/experiment_86/xmf/tin.time95.xmf
# reading Experiments/experiment_86/h5/tin.time96.hdf5
# output will be Experiments/experiment_86/xmf/tin.time96.xmf
# reading Experiments/experiment_86/h5/tin.time97.hdf5
# output will be Experiments/experiment_86/xmf/tin.time97.xmf
# reading Experiments/experiment_86/h5/tin.time98.hdf5
# output will be Experiments/experiment_86/xmf/tin.time98.xmf
# reading Experiments/experiment_86/h5/tin.time99.hdf5
# output will be Experiments/experiment_86/xmf/tin.time99.xmf
# reading Experiments/experiment_86/h5/tin.time100.hdf5
# output will be Experiments/experiment_86/xmf/tin.time100.xmf
# reading Experiments/experiment_86/h5/tin.time101.hdf5
# output will be Experiments/experiment_86/xmf/tin.time101.xmf
# reading Experiments/experiment_86/h5/tin.time102.hdf5
# output will be Experiments/experiment_86/xmf/tin.time102.xmf
# reading Experiments/experiment_86/h5/tin.time103.hdf5
# output will be Experiments/experiment_86/xmf/tin.time103.xmf
# reading Experiments/experiment_86/h5/tin.time104.hdf5
# output will be Experiments/experiment_86/xmf/tin.time104.xmf
# reading Experiments/experiment_86/h5/tin.time105.hdf5
# output will be Experiments/experiment_86/xmf/tin.time105.xmf
# reading Experiments/experiment_86/h5/tin.time106.hdf5
# output will be Experiments/experiment_86/xmf/tin.time106.xmf
# reading Experiments/experiment_86/h5/tin.time107.hdf5
# output will be Experiments/experiment_86/xmf/tin.time107.xmf
# reading Experiments/experiment_86/h5/tin.time108.hdf5
# output will be Experiments/experiment_86/xmf/tin.time108.xmf
# reading Experiments/experiment_86/h5/tin.time109.hdf5
# output will be Experiments/experiment_86/xmf/tin.time109.xmf
# reading Experiments/experiment_86/h5/tin.time110.hdf5
# output will be Experiments/experiment_86/xmf/tin.time110.xmf
# reading Experiments/experiment_86/h5/tin.time111.hdf5
# output will be Experiments/experiment_86/xmf/tin.time111.xmf
# reading Experiments/experiment_86/h5/tin.time112.hdf5
# output will be Experiments/experiment_86/xmf/tin.time112.xmf
# reading Experiments/experiment_86/h5/tin.time113.hdf5
# output will be Experiments/experiment_86/xmf/tin.time113.xmf
# reading Experiments/experiment_86/h5/tin.time114.hdf5
# output will be Experiments/experiment_86/xmf/tin.time114.xmf
# reading Experiments/experiment_86/h5/tin.time115.hdf5
# output will be Experiments/experiment_86/xmf/tin.time115.xmf
# reading Experiments/experiment_86/h5/tin.time116.hdf5
# output will be Experiments/experiment_86/xmf/tin.time116.xmf
# reading Experiments/experiment_86/h5/tin.time117.hdf5
# output will be Experiments/experiment_86/xmf/tin.time117.xmf
# reading Experiments/experiment_86/h5/tin.time118.hdf5
# output will be Experiments/experiment_86/xmf/tin.time118.xmf
# reading Experiments/experiment_86/h5/tin.time119.hdf5
# output will be Experiments/experiment_86/xmf/tin.time119.xmf
# reading Experiments/experiment_86/h5/tin.time120.hdf5
# output will be Experiments/experiment_86/xmf/tin.time120.xmf
# reading Experiments/experiment_86/h5/tin.time121.hdf5
# output will be Experiments/experiment_86/xmf/tin.time121.xmf
# reading Experiments/experiment_86/h5/tin.time122.hdf5
# output will be Experiments/experiment_86/xmf/tin.time122.xmf
# reading Experiments/experiment_86/h5/tin.time123.hdf5
# output will be Experiments/experiment_86/xmf/tin.time123.xmf
# reading Experiments/experiment_86/h5/tin.time124.hdf5
# output will be Experiments/experiment_86/xmf/tin.time124.xmf
# reading Experiments/experiment_86/h5/tin.time125.hdf5
# output will be Experiments/experiment_86/xmf/tin.time125.xmf
# reading Experiments/experiment_86/h5/tin.time126.hdf5
# output will be Experiments/experiment_86/xmf/tin.time126.xmf
# reading Experiments/experiment_86/h5/tin.time127.hdf5
# output will be Experiments/experiment_86/xmf/tin.time127.xmf
# reading Experiments/experiment_86/h5/tin.time128.hdf5
# output will be Experiments/experiment_86/xmf/tin.time128.xmf
# reading Experiments/experiment_86/h5/tin.time129.hdf5
# output will be Experiments/experiment_86/xmf/tin.time129.xmf
# reading Experiments/experiment_86/h5/tin.time130.hdf5
# output will be Experiments/experiment_86/xmf/tin.time130.xmf
# reading Experiments/experiment_86/h5/tin.time131.hdf5
# output will be Experiments/experiment_86/xmf/tin.time131.xmf
# reading Experiments/experiment_86/h5/tin.time132.hdf5
# output will be Experiments/experiment_86/xmf/tin.time132.xmf
# reading Experiments/experiment_86/h5/tin.time133.hdf5
# output will be Experiments/experiment_86/xmf/tin.time133.xmf
# reading Experiments/experiment_86/h5/tin.time134.hdf5
# output will be Experiments/experiment_86/xmf/tin.time134.xmf
# reading Experiments/experiment_86/h5/tin.time135.hdf5
# output will be Experiments/experiment_86/xmf/tin.time135.xmf
# reading Experiments/experiment_86/h5/tin.time136.hdf5
# output will be Experiments/experiment_86/xmf/tin.time136.xmf
# reading Experiments/experiment_86/h5/tin.time137.hdf5
# output will be Experiments/experiment_86/xmf/tin.time137.xmf
# reading Experiments/experiment_86/h5/tin.time138.hdf5
# output will be Experiments/experiment_86/xmf/tin.time138.xmf
# reading Experiments/experiment_86/h5/tin.time139.hdf5
# output will be Experiments/experiment_86/xmf/tin.time139.xmf
# reading Experiments/experiment_86/h5/tin.time140.hdf5
# output will be Experiments/experiment_86/xmf/tin.time140.xmf
# reading Experiments/experiment_86/h5/tin.time141.hdf5
# output will be Experiments/experiment_86/xmf/tin.time141.xmf
# reading Experiments/experiment_86/h5/tin.time142.hdf5
# output will be Experiments/experiment_86/xmf/tin.time142.xmf
# reading Experiments/experiment_86/h5/tin.time143.hdf5
# output will be Experiments/experiment_86/xmf/tin.time143.xmf
# reading Experiments/experiment_86/h5/tin.time144.hdf5
# output will be Experiments/experiment_86/xmf/tin.time144.xmf
# reading Experiments/experiment_86/h5/tin.time145.hdf5
# output will be Experiments/experiment_86/xmf/tin.time145.xmf
# reading Experiments/experiment_86/h5/tin.time146.hdf5
# output will be Experiments/experiment_86/xmf/tin.time146.xmf
# reading Experiments/experiment_86/h5/tin.time147.hdf5
# output will be Experiments/experiment_86/xmf/tin.time147.xmf
# reading Experiments/experiment_86/h5/tin.time148.hdf5
# output will be Experiments/experiment_86/xmf/tin.time148.xmf
# reading Experiments/experiment_86/h5/tin.time149.hdf5
# output will be Experiments/experiment_86/xmf/tin.time149.xmf
# reading Experiments/experiment_86/h5/tin.time150.hdf5
# output will be Experiments/experiment_86/xmf/tin.time150.xmf
# reading Experiments/experiment_86/h5/tin.time151.hdf5
# output will be Experiments/experiment_86/xmf/tin.time151.xmf
# reading Experiments/experiment_86/h5/tin.time152.hdf5
# output will be Experiments/experiment_86/xmf/tin.time152.xmf
# reading Experiments/experiment_86/h5/tin.time153.hdf5
# output will be Experiments/experiment_86/xmf/tin.time153.xmf
# reading Experiments/experiment_86/h5/tin.time154.hdf5
# output will be Experiments/experiment_86/xmf/tin.time154.xmf
# reading Experiments/experiment_86/h5/tin.time155.hdf5
# output will be Experiments/experiment_86/xmf/tin.time155.xmf
# reading Experiments/experiment_86/h5/tin.time156.hdf5
# output will be Experiments/experiment_86/xmf/tin.time156.xmf
# reading Experiments/experiment_86/h5/tin.time157.hdf5
# output will be Experiments/experiment_86/xmf/tin.time157.xmf
# reading Experiments/experiment_86/h5/tin.time158.hdf5
# output will be Experiments/experiment_86/xmf/tin.time158.xmf
# reading Experiments/experiment_86/h5/tin.time159.hdf5
# output will be Experiments/experiment_86/xmf/tin.time159.xmf
# reading Experiments/experiment_86/h5/tin.time160.hdf5
# output will be Experiments/experiment_86/xmf/tin.time160.xmf
# reading Experiments/experiment_86/h5/tin.time161.hdf5
# output will be Experiments/experiment_86/xmf/tin.time161.xmf
# reading Experiments/experiment_86/h5/tin.time162.hdf5
# output will be Experiments/experiment_86/xmf/tin.time162.xmf
# reading Experiments/experiment_86/h5/tin.time163.hdf5
# output will be Experiments/experiment_86/xmf/tin.time163.xmf
# reading Experiments/experiment_86/h5/tin.time164.hdf5
# output will be Experiments/experiment_86/xmf/tin.time164.xmf
# reading Experiments/experiment_86/h5/tin.time165.hdf5
# output will be Experiments/experiment_86/xmf/tin.time165.xmf
# reading Experiments/experiment_86/h5/tin.time166.hdf5
# output will be Experiments/experiment_86/xmf/tin.time166.xmf
# reading Experiments/experiment_86/h5/tin.time167.hdf5
# output will be Experiments/experiment_86/xmf/tin.time167.xmf
# reading Experiments/experiment_86/h5/tin.time168.hdf5
# output will be Experiments/experiment_86/xmf/tin.time168.xmf
# reading Experiments/experiment_86/h5/tin.time169.hdf5
# output will be Experiments/experiment_86/xmf/tin.time169.xmf
# reading Experiments/experiment_86/h5/tin.time170.hdf5
# output will be Experiments/experiment_86/xmf/tin.time170.xmf
# reading Experiments/experiment_86/h5/tin.time171.hdf5
# output will be Experiments/experiment_86/xmf/tin.time171.xmf
# reading Experiments/experiment_86/h5/tin.time172.hdf5
# output will be Experiments/experiment_86/xmf/tin.time172.xmf
# reading Experiments/experiment_86/h5/tin.time173.hdf5
# output will be Experiments/experiment_86/xmf/tin.time173.xmf
# reading Experiments/experiment_86/h5/tin.time174.hdf5
# output will be Experiments/experiment_86/xmf/tin.time174.xmf
# reading Experiments/experiment_86/h5/tin.time175.hdf5
# output will be Experiments/experiment_86/xmf/tin.time175.xmf
# reading Experiments/experiment_86/h5/tin.time176.hdf5
# output will be Experiments/experiment_86/xmf/tin.time176.xmf
# reading Experiments/experiment_86/h5/tin.time177.hdf5
# output will be Experiments/experiment_86/xmf/tin.time177.xmf
# reading Experiments/experiment_86/h5/tin.time178.hdf5
# output will be Experiments/experiment_86/xmf/tin.time178.xmf
# reading Experiments/experiment_86/h5/tin.time179.hdf5
# output will be Experiments/experiment_86/xmf/tin.time179.xmf
# reading Experiments/experiment_86/h5/tin.time180.hdf5
# output will be Experiments/experiment_86/xmf/tin.time180.xmf
# reading Experiments/experiment_86/h5/tin.time181.hdf5
# output will be Experiments/experiment_86/xmf/tin.time181.xmf
# reading Experiments/experiment_86/h5/tin.time182.hdf5
# output will be Experiments/experiment_86/xmf/tin.time182.xmf
# reading Experiments/experiment_86/h5/tin.time183.hdf5
# output will be Experiments/experiment_86/xmf/tin.time183.xmf
# reading Experiments/experiment_86/h5/tin.time184.hdf5
# output will be Experiments/experiment_86/xmf/tin.time184.xmf
# reading Experiments/experiment_86/h5/tin.time185.hdf5
# output will be Experiments/experiment_86/xmf/tin.time185.xmf
# reading Experiments/experiment_86/h5/tin.time186.hdf5
# output will be Experiments/experiment_86/xmf/tin.time186.xmf
# reading Experiments/experiment_86/h5/tin.time187.hdf5
# output will be Experiments/experiment_86/xmf/tin.time187.xmf
# reading Experiments/experiment_86/h5/tin.time188.hdf5
# output will be Experiments/experiment_86/xmf/tin.time188.xmf
# reading Experiments/experiment_86/h5/tin.time189.hdf5
# output will be Experiments/experiment_86/xmf/tin.time189.xmf
# reading Experiments/experiment_86/h5/tin.time190.hdf5
# output will be Experiments/experiment_86/xmf/tin.time190.xmf
# reading Experiments/experiment_86/h5/tin.time191.hdf5
# output will be Experiments/experiment_86/xmf/tin.time191.xmf
# reading Experiments/experiment_86/h5/tin.time192.hdf5
# output will be Experiments/experiment_86/xmf/tin.time192.xmf
# reading Experiments/experiment_86/h5/tin.time193.hdf5
# output will be Experiments/experiment_86/xmf/tin.time193.xmf
# reading Experiments/experiment_86/h5/tin.time194.hdf5
# output will be Experiments/experiment_86/xmf/tin.time194.xmf
# reading Experiments/experiment_86/h5/tin.time195.hdf5
# output will be Experiments/experiment_86/xmf/tin.time195.xmf
# reading Experiments/experiment_86/h5/tin.time196.hdf5
# output will be Experiments/experiment_86/xmf/tin.time196.xmf
# reading Experiments/experiment_86/h5/tin.time197.hdf5
# output will be Experiments/experiment_86/xmf/tin.time197.xmf
# reading Experiments/experiment_86/h5/tin.time198.hdf5
# output will be Experiments/experiment_86/xmf/tin.time198.xmf
# reading Experiments/experiment_86/h5/tin.time199.hdf5
# output will be Experiments/experiment_86/xmf/tin.time199.xmf
# reading Experiments/experiment_86/h5/tin.time200.hdf5
# output will be Experiments/experiment_86/xmf/tin.time200.xmf
# reading Experiments/experiment_86/h5/tin.time201.hdf5
# output will be Experiments/experiment_86/xmf/tin.time201.xmf
# reading Experiments/experiment_86/h5/tin.time202.hdf5
# output will be Experiments/experiment_86/xmf/tin.time202.xmf
# reading Experiments/experiment_86/h5/tin.time203.hdf5
# output will be Experiments/experiment_86/xmf/tin.time203.xmf
# reading Experiments/experiment_86/h5/tin.time204.hdf5
# output will be Experiments/experiment_86/xmf/tin.time204.xmf
# reading Experiments/experiment_86/h5/tin.time205.hdf5
# output will be Experiments/experiment_86/xmf/tin.time205.xmf
# reading Experiments/experiment_86/h5/tin.time206.hdf5
# output will be Experiments/experiment_86/xmf/tin.time206.xmf
# reading Experiments/experiment_86/h5/tin.time207.hdf5
# output will be Experiments/experiment_86/xmf/tin.time207.xmf
# reading Experiments/experiment_86/h5/tin.time208.hdf5
# output will be Experiments/experiment_86/xmf/tin.time208.xmf
# reading Experiments/experiment_86/h5/tin.time209.hdf5
# output will be Experiments/experiment_86/xmf/tin.time209.xmf
# reading Experiments/experiment_86/h5/tin.time210.hdf5
# output will be Experiments/experiment_86/xmf/tin.time210.xmf
# reading Experiments/experiment_86/h5/tin.time211.hdf5
# output will be Experiments/experiment_86/xmf/tin.time211.xmf
# reading Experiments/experiment_86/h5/tin.time212.hdf5
# output will be Experiments/experiment_86/xmf/tin.time212.xmf
# reading Experiments/experiment_86/h5/tin.time213.hdf5
# output will be Experiments/experiment_86/xmf/tin.time213.xmf
# reading Experiments/experiment_86/h5/tin.time214.hdf5
# output will be Experiments/experiment_86/xmf/tin.time214.xmf
# reading Experiments/experiment_86/h5/tin.time215.hdf5
# output will be Experiments/experiment_86/xmf/tin.time215.xmf
# reading Experiments/experiment_86/h5/tin.time216.hdf5
# output will be Experiments/experiment_86/xmf/tin.time216.xmf
# reading Experiments/experiment_86/h5/tin.time217.hdf5
# output will be Experiments/experiment_86/xmf/tin.time217.xmf
# reading Experiments/experiment_86/h5/tin.time218.hdf5
# output will be Experiments/experiment_86/xmf/tin.time218.xmf
# reading Experiments/experiment_86/h5/tin.time219.hdf5
# output will be Experiments/experiment_86/xmf/tin.time219.xmf
# reading Experiments/experiment_86/h5/tin.time220.hdf5
# output will be Experiments/experiment_86/xmf/tin.time220.xmf
# reading Experiments/experiment_86/h5/tin.time221.hdf5
# output will be Experiments/experiment_86/xmf/tin.time221.xmf
# reading Experiments/experiment_86/h5/tin.time222.hdf5
# output will be Experiments/experiment_86/xmf/tin.time222.xmf
# reading Experiments/experiment_86/h5/tin.time223.hdf5
# output will be Experiments/experiment_86/xmf/tin.time223.xmf
# reading Experiments/experiment_86/h5/tin.time224.hdf5
# output will be Experiments/experiment_86/xmf/tin.time224.xmf
# reading Experiments/experiment_86/h5/tin.time225.hdf5
# output will be Experiments/experiment_86/xmf/tin.time225.xmf
# reading Experiments/experiment_86/h5/tin.time226.hdf5
# output will be Experiments/experiment_86/xmf/tin.time226.xmf
# reading Experiments/experiment_86/h5/tin.time227.hdf5
# output will be Experiments/experiment_86/xmf/tin.time227.xmf
# reading Experiments/experiment_86/h5/tin.time228.hdf5
# output will be Experiments/experiment_86/xmf/tin.time228.xmf
# reading Experiments/experiment_86/h5/tin.time229.hdf5
# output will be Experiments/experiment_86/xmf/tin.time229.xmf
# reading Experiments/experiment_86/h5/tin.time230.hdf5
# output will be Experiments/experiment_86/xmf/tin.time230.xmf
# reading Experiments/experiment_86/h5/tin.time231.hdf5
# output will be Experiments/experiment_86/xmf/tin.time231.xmf
# reading Experiments/experiment_86/h5/tin.time232.hdf5
# output will be Experiments/experiment_86/xmf/tin.time232.xmf
# reading Experiments/experiment_86/h5/tin.time233.hdf5
# output will be Experiments/experiment_86/xmf/tin.time233.xmf
# reading Experiments/experiment_86/h5/tin.time234.hdf5
# output will be Experiments/experiment_86/xmf/tin.time234.xmf
# reading Experiments/experiment_86/h5/tin.time235.hdf5
# output will be Experiments/experiment_86/xmf/tin.time235.xmf
# reading Experiments/experiment_86/h5/tin.time236.hdf5
# output will be Experiments/experiment_86/xmf/tin.time236.xmf
# reading Experiments/experiment_86/h5/tin.time237.hdf5
# output will be Experiments/experiment_86/xmf/tin.time237.xmf
# reading Experiments/experiment_86/h5/tin.time238.hdf5
# output will be Experiments/experiment_86/xmf/tin.time238.xmf
# reading Experiments/experiment_86/h5/tin.time239.hdf5
# output will be Experiments/experiment_86/xmf/tin.time239.xmf
# reading Experiments/experiment_86/h5/tin.time240.hdf5
# output will be Experiments/experiment_86/xmf/tin.time240.xmf
# reading Experiments/experiment_86/h5/tin.time241.hdf5
# output will be Experiments/experiment_86/xmf/tin.time241.xmf
# reading Experiments/experiment_86/h5/tin.time242.hdf5
# output will be Experiments/experiment_86/xmf/tin.time242.xmf
# reading Experiments/experiment_86/h5/tin.time243.hdf5
# output will be Experiments/experiment_86/xmf/tin.time243.xmf
# reading Experiments/experiment_86/h5/tin.time244.hdf5
# output will be Experiments/experiment_86/xmf/tin.time244.xmf
# reading Experiments/experiment_86/h5/tin.time245.hdf5
# output will be Experiments/experiment_86/xmf/tin.time245.xmf
# reading Experiments/experiment_86/h5/tin.time246.hdf5
# output will be Experiments/experiment_86/xmf/tin.time246.xmf
# reading Experiments/experiment_86/h5/tin.time247.hdf5
# output will be Experiments/experiment_86/xmf/tin.time247.xmf
# reading Experiments/experiment_86/h5/tin.time248.hdf5
# output will be Experiments/experiment_86/xmf/tin.time248.xmf
# reading Experiments/experiment_86/h5/tin.time249.hdf5
# output will be Experiments/experiment_86/xmf/tin.time249.xmf
# reading Experiments/experiment_86/h5/tin.time250.hdf5
# output will be Experiments/experiment_86/xmf/tin.time250.xmf
# reading Experiments/experiment_86/h5/tin.time251.hdf5
# output will be Experiments/experiment_86/xmf/tin.time251.xmf
# reading Experiments/experiment_86/h5/tin.time252.hdf5
# output will be Experiments/experiment_86/xmf/tin.time252.xmf
# reading Experiments/experiment_86/h5/tin.time253.hdf5
# output will be Experiments/experiment_86/xmf/tin.time253.xmf
# reading Experiments/experiment_86/h5/tin.time254.hdf5
# output will be Experiments/experiment_86/xmf/tin.time254.xmf
# reading Experiments/experiment_86/h5/tin.time255.hdf5
# output will be Experiments/experiment_86/xmf/tin.time255.xmf
# reading Experiments/experiment_86/h5/tin.time256.hdf5
# output will be Experiments/experiment_86/xmf/tin.time256.xmf
# reading Experiments/experiment_86/h5/tin.time257.hdf5
# output will be Experiments/experiment_86/xmf/tin.time257.xmf
# reading Experiments/experiment_86/h5/tin.time258.hdf5
# output will be Experiments/experiment_86/xmf/tin.time258.xmf
# reading Experiments/experiment_86/h5/tin.time259.hdf5
# output will be Experiments/experiment_86/xmf/tin.time259.xmf
# reading Experiments/experiment_86/h5/tin.time260.hdf5
# output will be Experiments/experiment_86/xmf/tin.time260.xmf
# reading Experiments/experiment_86/h5/tin.time261.hdf5
# output will be Experiments/experiment_86/xmf/tin.time261.xmf
# reading Experiments/experiment_86/h5/tin.time262.hdf5
# output will be Experiments/experiment_86/xmf/tin.time262.xmf
# reading Experiments/experiment_86/h5/tin.time263.hdf5
# output will be Experiments/experiment_86/xmf/tin.time263.xmf
# reading Experiments/experiment_86/h5/tin.time264.hdf5
# output will be Experiments/experiment_86/xmf/tin.time264.xmf
# reading Experiments/experiment_86/h5/tin.time265.hdf5
# output will be Experiments/experiment_86/xmf/tin.time265.xmf
# reading Experiments/experiment_86/h5/tin.time266.hdf5
# output will be Experiments/experiment_86/xmf/tin.time266.xmf
# reading Experiments/experiment_86/h5/tin.time267.hdf5
# output will be Experiments/experiment_86/xmf/tin.time267.xmf
# reading Experiments/experiment_86/h5/tin.time268.hdf5
# output will be Experiments/experiment_86/xmf/tin.time268.xmf
# reading Experiments/experiment_86/h5/tin.time269.hdf5
# output will be Experiments/experiment_86/xmf/tin.time269.xmf
# reading Experiments/experiment_86/h5/tin.time270.hdf5
# output will be Experiments/experiment_86/xmf/tin.time270.xmf
# reading Experiments/experiment_86/h5/tin.time271.hdf5
# output will be Experiments/experiment_86/xmf/tin.time271.xmf
# reading Experiments/experiment_86/h5/tin.time272.hdf5
# output will be Experiments/experiment_86/xmf/tin.time272.xmf
# reading Experiments/experiment_86/h5/tin.time273.hdf5
# output will be Experiments/experiment_86/xmf/tin.time273.xmf
# reading Experiments/experiment_86/h5/tin.time274.hdf5
# output will be Experiments/experiment_86/xmf/tin.time274.xmf
# reading Experiments/experiment_86/h5/tin.time275.hdf5
# output will be Experiments/experiment_86/xmf/tin.time275.xmf
# reading Experiments/experiment_86/h5/tin.time276.hdf5
# output will be Experiments/experiment_86/xmf/tin.time276.xmf
# reading Experiments/experiment_86/h5/tin.time277.hdf5
# output will be Experiments/experiment_86/xmf/tin.time277.xmf
# reading Experiments/experiment_86/h5/tin.time278.hdf5
# output will be Experiments/experiment_86/xmf/tin.time278.xmf
# reading Experiments/experiment_86/h5/tin.time279.hdf5
# output will be Experiments/experiment_86/xmf/tin.time279.xmf
# reading Experiments/experiment_86/h5/tin.time280.hdf5
# output will be Experiments/experiment_86/xmf/tin.time280.xmf
# reading Experiments/experiment_86/h5/tin.time281.hdf5
# output will be Experiments/experiment_86/xmf/tin.time281.xmf
# reading Experiments/experiment_86/h5/tin.time282.hdf5
# output will be Experiments/experiment_86/xmf/tin.time282.xmf
# reading Experiments/experiment_86/h5/tin.time283.hdf5
# output will be Experiments/experiment_86/xmf/tin.time283.xmf
# reading Experiments/experiment_86/h5/tin.time284.hdf5
# output will be Experiments/experiment_86/xmf/tin.time284.xmf
# reading Experiments/experiment_86/h5/tin.time285.hdf5
# output will be Experiments/experiment_86/xmf/tin.time285.xmf
# reading Experiments/experiment_86/h5/tin.time286.hdf5
# output will be Experiments/experiment_86/xmf/tin.time286.xmf
# reading Experiments/experiment_86/h5/tin.time287.hdf5
# output will be Experiments/experiment_86/xmf/tin.time287.xmf
# reading Experiments/experiment_86/h5/tin.time288.hdf5
# output will be Experiments/experiment_86/xmf/tin.time288.xmf
# reading Experiments/experiment_86/h5/tin.time289.hdf5
# output will be Experiments/experiment_86/xmf/tin.time289.xmf
# reading Experiments/experiment_86/h5/tin.time290.hdf5
# output will be Experiments/experiment_86/xmf/tin.time290.xmf
# reading Experiments/experiment_86/h5/tin.time291.hdf5
# output will be Experiments/experiment_86/xmf/tin.time291.xmf
# reading Experiments/experiment_86/h5/tin.time292.hdf5
# output will be Experiments/experiment_86/xmf/tin.time292.xmf
# reading Experiments/experiment_86/h5/tin.time293.hdf5
# output will be Experiments/experiment_86/xmf/tin.time293.xmf
# reading Experiments/experiment_86/h5/tin.time294.hdf5
# output will be Experiments/experiment_86/xmf/tin.time294.xmf
# reading Experiments/experiment_86/h5/tin.time295.hdf5
# output will be Experiments/experiment_86/xmf/tin.time295.xmf
# reading Experiments/experiment_86/h5/tin.time296.hdf5
# output will be Experiments/experiment_86/xmf/tin.time296.xmf
# reading Experiments/experiment_86/h5/tin.time297.hdf5
# output will be Experiments/experiment_86/xmf/tin.time297.xmf
# reading Experiments/experiment_86/h5/tin.time298.hdf5
# output will be Experiments/experiment_86/xmf/tin.time298.xmf
# reading Experiments/experiment_86/h5/tin.time299.hdf5
# output will be Experiments/experiment_86/xmf/tin.time299.xmf
# reading Experiments/experiment_86/h5/tin.time300.hdf5
# output will be Experiments/experiment_86/xmf/tin.time300.xmf

# %%
for i in range(len(attribs)):
    print(attribs[i])
    print (attribs_inter[i].shape)

# %%
tin=ppu.TINfile()
tin.loadTIN(tin_file)
flow=ppu.Flowfile()
flow.loadFlow(flow_file)
attribs_inter=[]

# %%
len(tin.x)
